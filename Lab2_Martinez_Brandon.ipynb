# %% [markdown]
# <a href="https://colab.research.google.com/github/FenixG01/Martinez-Gamboa-Brandon-structured-programming/blob/main/Lab2_Martinez_Brandon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code 1

# %%
def multiply(a, b):
    return a * b
print(multiply(3, 4))

"""In this is original code"""

# %% [markdown]
# Code 2

# %%
counter=0
for i in range(10):
    counter += 1
print(counter)
"""In this is I changed the range by 10"""

# %% [markdown]
# Code 3

# %%
age= int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
    """In this I add the : affter 18 by eliminate de SyntaxisError"""

# %% [markdown]
# Code 4

# %%
a=5
b=6
temp= a
a= b
b= temp
print(a)
print(b)
"""I Changed the values by a and b"""
