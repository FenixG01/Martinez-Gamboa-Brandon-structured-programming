# %% [markdown]
# <a href="https://colab.research.google.com/github/FenixG01/Martinez-Gamboa-Brandon-structured-programming/blob/main/lab1_martinez_brandon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code A

# %%
grades=[80,90,70]
average=sum(grades)/len(grades)
print(average)

# %% [markdown]
# Code B

# %%
def calculate_average(data):
    return sum(data)/len(data)
grades=[80,90,70]
print(calculate_average(grades))

# %% [markdown]
# Code C

# %%
numbers= [1,2,3,4,5]
squares =list(map(lambda x: x**2,numbers))
print(squares)

# %%
numbers= [1,2,3,4,5]
squares =list(map(lambda x: x**2,numbers))
print(squares)
